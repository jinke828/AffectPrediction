# %%
import numpy as np
import pandas as pd
import os
from sklearn import svm
from sklearn import metrics
import scipy.io
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats, linalg
import warnings
from sklearn.exceptions import ConvergenceWarning
def conv_r2z(r):
    with np.errstate(invalid='ignore', divide='ignore'):
        return 0.5 * (np.log(1 + r) - np.log(1 - r))
def conv_z2r(z):
    with np.errstate(invalid='ignore', divide='ignore'):
        return (np.exp(2 * z) - 1) / (np.exp(2 * z) + 1)
# %matplotlib inline

# %%
dataset_learn = "FNL"

base_path = os.path.dirname(os.path.dirname(os.getcwd()))
path = base_path + '/data'
nR = 122
thres = 0.01

nsubj = 35
wsize = 23
nT = 1364

print('  model learn from = '+str(dataset_learn)+' win'+str(wsize))
# Out:
#   model learn from = FNL win23

# %% [markdown]
# # load Behavioral Data

# %%
# load valence
valence_learn = scipy.io.loadmat(path + '/beh/preprocessed/group_average/conv_slidingBeh/FNL_valence.mat')['sliding_beh']
valence_learn = np.squeeze(valence_learn)

# load arousal
arousal_learn = scipy.io.loadmat(path + '/beh/preprocessed/group_average/conv_slidingBeh/FNL_arousal.mat')['sliding_beh']
arousal_learn = np.squeeze(arousal_learn)

print('model learn: valence shape' + str(valence_learn.shape))
print('model learn: arousal shape' + str(arousal_learn.shape))
# Out:
# model learn: valence shape(1341,)
# model learn: arousal shape(1341,)

# %%
# plot and run correlation
time_learn = range(1341)

fig, ax = plt.subplots()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.plot(time_learn, valence_learn, color = 'blue')
plt.plot(time_learn, arousal_learn, color = 'red')
plt.ylim([-3.99, 3])
plt.yticks(np.arange(-3,3,1.5))
plt.xticks(np.arange(0,2000,500))
plt.xlabel('Time (s)')
plt.ylabel('Z-score')
fig.set_dpi(800)
plt.show()

# %% [markdown]
# # Load Brain Data

# %%
import mat73
dynFC_learn = mat73.loadmat(path + '/brain/' + dataset_learn + '/a_output/FC/sliding-dynFeat.mat')['dynFeat']
# zscore per feature
dynFC_learn = scipy.stats.zscore(dynFC_learn,2,nan_policy='omit') 
print('  model learn: brain entire feature shape '+str(dynFC_learn.shape))
# Out:
#   model learn: brain entire feature shape (35, 7381, 1341)

# %% [markdown]
# # Leave-one-subject-out Cross-validation

# %%
def losocv(fmri, behavior, nsubj, rvals):
    output_acc, output_eval, output_pos_feat, output_neg_feat = [], [], np.zeros((nsubj, nR, nR)), np.zeros((nsubj, nR, nR))
    for test_sub in range(nsubj):
        
        # separate train-test subject
        test_fmri = fmri[test_sub,:,:]
        train_fmri = np.delete(fmri,test_sub,0)

        # every training participants' data are concatenated
        # fed as independent instances to the model
        train_feature = np.transpose(train_fmri,(1,0,2))
        train_feature = np.reshape(train_feature,(train_feature.shape[0],train_feature.shape[1]*train_feature.shape[2]))
        train_behavior = []
        for sub in range(nsubj-1):
            train_behavior.append(behavior)
        train_behavior = np.asarray(train_behavior)
        train_behavior = np.reshape(train_behavior,(train_behavior.shape[0]*train_behavior.shape[1]))

        # features: correlation with behavior
        train_subj_corrmat = np.delete(rvals,test_sub,0)

        # feature selection
        pos_feat, neg_feat, all_feat, nanval = [], [], [], 0
        idx = -1
        for feat in range(int(nR*(nR-1)/2)):
            idx=idx+1
                
            if np.any(np.isnan(train_subj_corrmat[:,feat])):
                nanval = nanval+1
                pass
            else:
                [tval,pval] = scipy.stats.ttest_1samp(train_subj_corrmat[:,feat],0)
                if pval < thres:
                    if np.average(train_subj_corrmat[:,feat])>0:
                        all_feat.append(idx)
                        pos_feat.append(idx)
                    elif np.average(train_subj_corrmat[:,feat])<0:
                        all_feat.append(idx)
                        neg_feat.append(idx)
        pos_feat, neg_feat, all_feat = np.asarray(pos_feat), np.asarray(neg_feat), np.asarray(all_feat)

        # summarize feature matrix
        idx = -1
        for i1 in range(nR-1):
            for i2 in range(i1+1,nR):
                idx = idx+1
                if idx in pos_feat:
                    output_pos_feat[test_sub,i1,i2]=1
                    output_pos_feat[test_sub,i2,i1]=1
                if idx in neg_feat:
                    output_neg_feat[test_sub,i1,i2]=1
                    output_neg_feat[test_sub,i2,i1]=1

        train_selected_feat = train_feature[all_feat,:]
        test_selected_feat = test_fmri[all_feat, :]
        test_behavior = behavior

        # if any of the TRs are removed
        rmtr_train = []
        for tm in range(train_selected_feat.shape[1]):
            if np.all(np.isnan(train_selected_feat[:,tm])):
                rmtr_train.append(tm)
        rmtr_train = np.asarray(rmtr_train)
        if len(rmtr_train)>0:
            train_selected_feat = np.delete(train_selected_feat,rmtr_train,1)
            train_behavior = np.delete(train_behavior,rmtr_train,0)

        rmtr_test = []
        for tm in range(test_selected_feat.shape[1]):
            if np.all(np.isnan(test_selected_feat[:, tm])):
                rmtr_test.append(tm)
        rmtr_test = np.asarray(rmtr_test)
        if len(rmtr_test) > 0:
            test_selected_feat = np.delete(test_selected_feat, rmtr_test, 1)
            test_behavior = np.delete(test_behavior,rmtr_test,0)

        # Support vector regression with non-linear kernel
        clf = []
        clf = svm.SVR(kernel='rbf',max_iter=1000, gamma='auto')
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=ConvergenceWarning)
            clf.fit(train_selected_feat.T, train_behavior)
        predicted = clf.predict(test_selected_feat.T)
        output_acc.append(predicted)

        # evaluate
        pearsonr = scipy.stats.pearsonr(test_behavior, predicted)
        mse = metrics.mean_squared_error(test_behavior, predicted)
        rsq = metrics.r2_score(test_behavior, predicted)
        output_eval.append([pearsonr[0], mse, rsq])
        print('  subj '+str(test_sub+1)+' / '+str(nsubj)+': #feat '+str(len(all_feat))+', pearson r='+str(np.round(pearsonr[0],3)),', mse='+str(np.round(mse,3))+', rsq='+str(np.round(rsq,3)))
        print('               (train) ft '+str(train_selected_feat.shape[1])+', beh '+str(train_behavior.shape[0])+
              ', (test) ft '+str(test_selected_feat.shape[1])+', beh '+str(test_behavior.shape[0]))

    output_acc, output_eval, output_pos_feat, output_neg_feat = np.asarray(output_acc), np.asarray(output_eval), np.asarray(output_pos_feat), np.asarray(output_neg_feat)
    return output_acc, output_eval, output_pos_feat, output_neg_feat

# %% [markdown]
# # Valence

# %%
# calculate correlation with behavior for all FC features
allsubj_corrmat = np.zeros((nsubj,int(nR*(nR-1)/2)))

for sub in range(nsubj):
    for feat in range(int(nR*(nR-1)/2)):
        if np.any(np.isnan(dynFC_learn[sub,feat,:]))==True:
            rval=np.nan
        else:
            [rval,pval] = scipy.stats.pearsonr(dynFC_learn[sub,feat,:], valence_learn)
        allsubj_corrmat[sub,feat] = rval
print(allsubj_corrmat.shape)
# Out:
# (35, 7381)

# %%
[output_acc_valence, output_eval_valence, output_pos_feat_valence, output_neg_feat_valence] = losocv(dynFC_learn, valence_learn, nsubj, allsubj_corrmat)
# Out:
#   subj 1 / 35: #feat 1139, pearson r=0.621 , mse=0.628, rsq=0.371
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 2 / 35: #feat 1302, pearson r=0.585 , mse=0.707, rsq=0.293
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 3 / 35: #feat 1176, pearson r=0.51 , mse=0.747, rsq=0.252
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 4 / 35: #feat 1214, pearson r=0.492 , mse=0.759, rsq=0.24
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 5 / 35: #feat 1169, pearson r=0.434 , mse=0.817, rsq=0.182
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 6 / 35: #feat 1168, pearson r=0.6 , mse=0.655, rsq=0.344
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 7 / 35: #feat 1200, pearson r=0.298 , mse=0.921, rsq=0.078
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 8 / 35: #feat 1186, pearson r=0.412 , mse=0.839, rsq=0.16
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 9 / 35: #feat 1169, pearson r=0.447 , mse=0.805, rsq=0.195
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 10 / 35: #feat 1139, pearson r=0.539 , mse=0.71, rsq=0.29
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 11 / 35: #feat 1224, pearson r=0.65 , mse=0.586, rsq=0.414
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 12 / 35: #feat 1245, pearson r=0.513 , mse=0.751, rsq=0.249
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 13 / 35: #feat 1275, pearson r=0.345 , mse=0.903, rsq=0.097
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 14 / 35: #feat 1240, pearson r=0.699 , mse=0.56, rsq=0.44
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 15 / 35: #feat 1158, pearson r=0.538 , mse=0.71, rsq=0.289
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 16 / 35: #feat 1250, pearson r=0.196 , mse=0.98, rsq=0.02
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 17 / 35: #feat 1207, pearson r=0.628 , mse=0.628, rsq=0.372
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 18 / 35: #feat 1132, pearson r=0.557 , mse=0.71, rsq=0.29
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 19 / 35: #feat 1183, pearson r=0.379 , mse=0.859, rsq=0.14
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 20 / 35: #feat 1167, pearson r=0.475 , mse=0.775, rsq=0.224
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 21 / 35: #feat 1167, pearson r=0.445 , mse=0.804, rsq=0.196
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 22 / 35: #feat 1226, pearson r=0.614 , mse=0.646, rsq=0.354
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 23 / 35: #feat 1171, pearson r=0.65 , mse=0.586, rsq=0.414
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 24 / 35: #feat 1180, pearson r=0.631 , mse=0.608, rsq=0.392
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 25 / 35: #feat 1114, pearson r=0.637 , mse=0.598, rsq=0.401
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 26 / 35: #feat 1258, pearson r=-0.005 , mse=1.14, rsq=-0.141
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 27 / 35: #feat 1167, pearson r=0.481 , mse=0.769, rsq=0.231
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 28 / 35: #feat 1175, pearson r=0.665 , mse=0.565, rsq=0.434
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 29 / 35: #feat 1210, pearson r=0.416 , mse=0.832, rsq=0.167
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 30 / 35: #feat 1207, pearson r=0.573 , mse=0.681, rsq=0.318
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 31 / 35: #feat 1154, pearson r=0.673 , mse=0.569, rsq=0.43
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 32 / 35: #feat 1169, pearson r=0.476 , mse=0.775, rsq=0.224
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 33 / 35: #feat 1274, pearson r=0.393 , mse=0.858, rsq=0.141
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 34 / 35: #feat 1219, pearson r=0.454 , mse=0.805, rsq=0.194
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 35 / 35: #feat 1178, pearson r=0.568 , mse=0.691, rsq=0.309
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341

# %%
fig, axs = plt.subplots(1,3)
axs[0].hist(output_eval_valence[:,0])
axs[0].set_title('Pearson correlation')
axs[1].hist(output_eval_valence[:,1])
axs[1].set_title('MSE')
axs[2].hist(output_eval_valence[:,2])
axs[2].set_title('r-squared')

print('Prediction result (mean of cross-validations): valence')
print(' pearson r = '+str(np.round(conv_z2r(np.mean(conv_r2z(output_eval_valence[:,0]))),3)))
print(' MSE       = '+str(np.round(np.mean(output_eval_valence[:,1]),3)))
print(' r-squared = '+str(np.round(np.mean(output_eval_valence[:,2]),3)))
# Out:
# Prediction result (mean of cross-validations): valence
#  pearson r = 0.514
#  MSE       = 0.742
#  r-squared = 0.257

# %%
savepath= base_path + '/results/sherlock/within_prediction/'
result = {'acc':output_acc_valence, 'eval':output_eval_valence, 'pos_feat':output_pos_feat_valence, 'neg_feat':output_neg_feat_valence}
if os.path.exists(savepath)==0:
    os.makedirs(savepath)
scipy.io.savemat(savepath+'sliding_valence.mat',result)

# %% [markdown]
# # Arousal

# %%
# calculate correlation with behavior for all FC features
allsubj_corrmat = np.zeros((nsubj,int(nR*(nR-1)/2)))

for sub in range(nsubj):
    for feat in range(int(nR*(nR-1)/2)):
        if np.any(np.isnan(dynFC_learn[sub,feat,:]))==True:
            rval=np.nan
        else:
            [rval,pval] = scipy.stats.pearsonr(dynFC_learn[sub,feat,:], arousal_learn)
        allsubj_corrmat[sub,feat] = rval
print(allsubj_corrmat.shape)
# Out:
# (35, 7381)

# %%
[output_acc_arousal, output_eval_arousal, output_pos_feat_arousal, output_neg_feat_arousal] = losocv(dynFC_learn, arousal_learn, nsubj, allsubj_corrmat)
# Out:
#   subj 1 / 35: #feat 1765, pearson r=0.797 , mse=0.387, rsq=0.612
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 2 / 35: #feat 1892, pearson r=0.507 , mse=0.744, rsq=0.255
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 3 / 35: #feat 1838, pearson r=0.747 , mse=0.461, rsq=0.539
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 4 / 35: #feat 1787, pearson r=0.757 , mse=0.427, rsq=0.573
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 5 / 35: #feat 1801, pearson r=0.752 , mse=0.459, rsq=0.541
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 6 / 35: #feat 1804, pearson r=0.763 , mse=0.437, rsq=0.563
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 7 / 35: #feat 1816, pearson r=0.68 , mse=0.552, rsq=0.448
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 8 / 35: #feat 1801, pearson r=0.736 , mse=0.478, rsq=0.521
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 9 / 35: #feat 1860, pearson r=0.524 , mse=0.727, rsq=0.272
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 10 / 35: #feat 1854, pearson r=0.743 , mse=0.477, rsq=0.523
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 11 / 35: #feat 1756, pearson r=0.848 , mse=0.295, rsq=0.704
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 12 / 35: #feat 1790, pearson r=0.753 , mse=0.442, rsq=0.557
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 13 / 35: #feat 1807, pearson r=0.616 , mse=0.629, rsq=0.371
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 14 / 35: #feat 1821, pearson r=0.699 , mse=0.564, rsq=0.435
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 15 / 35: #feat 1814, pearson r=0.719 , mse=0.501, rsq=0.499
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 16 / 35: #feat 1822, pearson r=0.599 , mse=0.688, rsq=0.312
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 17 / 35: #feat 1753, pearson r=0.757 , mse=0.429, rsq=0.57
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 18 / 35: #feat 1871, pearson r=0.668 , mse=0.558, rsq=0.441
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 19 / 35: #feat 1810, pearson r=0.726 , mse=0.515, rsq=0.484
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 20 / 35: #feat 1805, pearson r=0.793 , mse=0.391, rsq=0.609
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 21 / 35: #feat 1822, pearson r=0.673 , mse=0.597, rsq=0.403
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 22 / 35: #feat 1788, pearson r=0.723 , mse=0.525, rsq=0.475
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 23 / 35: #feat 1762, pearson r=0.867 , mse=0.302, rsq=0.697
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 24 / 35: #feat 1760, pearson r=0.828 , mse=0.326, rsq=0.674
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 25 / 35: #feat 1881, pearson r=0.771 , mse=0.416, rsq=0.584
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 26 / 35: #feat 1882, pearson r=0.336 , mse=0.891, rsq=0.109
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 27 / 35: #feat 1824, pearson r=0.693 , mse=0.527, rsq=0.473
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 28 / 35: #feat 1774, pearson r=0.825 , mse=0.324, rsq=0.676
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 29 / 35: #feat 1788, pearson r=0.808 , mse=0.388, rsq=0.612
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 30 / 35: #feat 1778, pearson r=0.806 , mse=0.37, rsq=0.629
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 31 / 35: #feat 1766, pearson r=0.826 , mse=0.321, rsq=0.679
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 32 / 35: #feat 1826, pearson r=0.715 , mse=0.516, rsq=0.484
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 33 / 35: #feat 1812, pearson r=0.701 , mse=0.552, rsq=0.447
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 34 / 35: #feat 1815, pearson r=0.736 , mse=0.473, rsq=0.527
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341
#   subj 35 / 35: #feat 1813, pearson r=0.739 , mse=0.484, rsq=0.515
#                (train) ft 45594, beh 45594, (test) ft 1341, beh 1341

# %%
fig, axs = plt.subplots(1,3)
axs[0].hist(output_eval_arousal[:,0])
axs[0].set_title('Pearson correlation')
axs[1].hist(output_eval_arousal[:,1])
axs[1].set_title('MSE')
axs[2].hist(output_eval_arousal[:,2])
axs[2].set_title('r-squared')

print('Prediction result (mean of cross-validations): arousal')
print(' pearson r = '+str(np.round(conv_z2r(np.mean(conv_r2z(output_eval_arousal[:,0]))),3)))
print(' MSE       = '+str(np.round(np.mean(output_eval_arousal[:,1]),3)))
print(' r-squared = '+str(np.round(np.mean(output_eval_arousal[:,2]),3)))
# Out:
# Prediction result (mean of cross-validations): arousal
#  pearson r = 0.734
#  MSE       = 0.491
#  r-squared = 0.509

# %%
savepath= base_path + '/results/sherlock/within_prediction/'
result = {'acc':output_acc_arousal, 'eval':output_eval_arousal, 'pos_feat':output_pos_feat_arousal, 'neg_feat':output_neg_feat_arousal}
if os.path.exists(savepath)==0:
    os.makedirs(savepath)
scipy.io.savemat(savepath+'/sliding_arousal.mat',result)
